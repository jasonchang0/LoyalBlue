# %%
import pandas as pd

# %%
import os

# %%
os.chdir('../data')

# %%
airport_pos = pd.read_csv('airportLatLng.csv')

# %%
cities = pd.read_csv('cities.csv')

# %%
routes = pd.read_csv('routes.txt', sep=',')

# %%
airports = pd.read_csv('usa_airports.csv')

# %%
airport_pos.head()
# Out:
#   index        lat         lng
# 0   ABQ  35.040222 -106.609194
# 1   ACK  41.253053  -70.060181
# 2   ALB  42.748712  -73.805498
# 3   ANC  61.174361 -149.996361
# 4   ANU  17.085693  -61.789703

# %%
cities.head()
# Out:
#        index                                                RIC  \
# 0   Airports  {'Code': 'RIC', 'City': 'Richmond', 'Name': 'R...
# 1  Countries                                                NaN
# 2    Regions                                                NaN
#
#                                                  PHX  \
# 0  {'Code': 'PHX', 'City': 'Phoenix', 'Name': 'Ph...
# 1                                                NaN
# 2                                                NaN
#
#                                                  MSY  \
# 0  {'Code': 'MSY', 'City': 'New Orleans', 'Name':...
# 1                                                NaN
# 2                                                NaN
#
#                                                  EWR  \
# 0  {'Code': 'EWR', 'City': 'Newark', 'Name': 'New...
# 1                                                NaN
# 2                                                NaN
#
# ...

# %%
routes.head()
# Out:
#   city1 city2 city3  mint  seasonal
# 0   ABQ     0   JFK     0         0
# 1   ABQ   JFK   ACK     0         1
# 2   ABQ   JFK   ANU     0         0
# 3   ABQ   JFK   AUA     1         0
# 4   ABQ   JFK   BDA     0         0

# %%
airports.head()
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# ...

# %%
routes[routes.city1 == 'JFK']
# Out:
#      city1 city2 city3  mint  seasonal
# 2852   JFK     0   ABQ     0         0
# 2853   JFK     0   ACK     0         1
# 2854   JFK     0   ANU     0         0
# 2855   JFK     0   ATL     0         0
# 2856   JFK     0   AUA     1         0
# 2857   JFK     0   AUS     0         0
# 2858   JFK     0   BDA     0         0
# 2859   JFK     0   BGI     1         0
# 2860   JFK     0   BOS     0         0
# 2861   JFK     0   BQN     0         0
# 2862   JFK     0   BTV     0         0
# 2863   JFK     0   BUF     0         0
# 2864   JFK     0   BUR     0         0
# 2865   JFK     0   CHS     0         0
# 2866   JFK     0   CLT     0         0
# 2867   JFK     0   CTG     0         0
# 2868   JFK     0   CUN     0         0
# 2869   JFK     0   CUR     0         0
# 2870   JFK     0   DAB     0         0
# 2871   JFK     0   DEN     0         0
# 2872   JFK     0   FLL     0         0
# 2873   JFK     0   GCM     0         0
# 2874   JFK     0   GND     1         1
# ...

# %%
routes.columns
# Out:
# Index(['city1', 'city2', 'city3', 'mint', 'seasonal'], dtype='object')
